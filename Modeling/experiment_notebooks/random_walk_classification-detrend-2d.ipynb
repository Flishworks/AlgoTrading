# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

sys.path.append(r'C:\Users\avido\Documents\other code\AlgoTrading')
import utils

sys.path.append(r'C:\Users\avido\Documents\other code\Signal_processing_and_timeseries_exploration')
import dsp_utils as dsp

# %%
#open and combine all data
folder = os.path.join('..', 'data', 'scraped_OHLC')
key = 'close'
coins = ['BTC', 'ETH', 'SOL']
window_size = 28*28

prices = []
random_walks = []
for file in os.listdir(folder):
    if not file.startswith(tuple(coins)):
        continue
    vals = pd.read_csv(os.path.join(folder, file))[key].values.tolist()
    print(f'file: {file}, norm std of diffs: {np.std(np.diff(vals))/np.mean(vals)}')
    
    # log transform, standardize, then apply high pass filter
    #drop zero values 
    vals = np.array(vals)
    # vals = vals[vals != 0]
    # vals = np.log(vals)
    vals = dsp.standardize(vals)
    ema = dsp.apply_ema(vals, 0.01)
    detrended = vals - ema
    prices.extend(detrended)
    dts = np.diff(vals)
    dts = dsp.remove_outliers(dts) #remove outliers
    random_walk = dsp.empiricle_random_walk(len(vals), dts = dts)
    ema = dsp.apply_ema(random_walk, 0.01)
    detrended = random_walk - ema
    random_walks.extend(detrended)
    
    

#convert to numpy array

prices = np.array(prices).reshape(1, -1)
random_walks = np.array(random_walks).reshape(1, -1)

#reshape 
# final_len = len(prices) - len(prices) % window_size
# prices = prices[0:final_len].reshape(-1, window_size)
# random_walks = random_walks[0:final_len].reshape(-1, window_size)
prices = dsp.segment_with_overlap(prices, seg_n = window_size, overlap_n = window_size*9//10)
prices = np.swapaxes(prices, 0, 1)
random_walks = dsp.segment_with_overlap(random_walks, seg_n = window_size, overlap_n = window_size*9//10)
random_walks = np.swapaxes(random_walks, 0, 1)

#normalize each window  so origin = 1
# prices = prices/prices[:, 0, 0]
# random_walks = random_walks/random_walks[:, 0, 0]

# drop na
idxs2drop = np.isnan(prices).any(axis=-1)
prices = prices[~idxs2drop]
random_walks = random_walks[~idxs2drop]
# Out:
# file: BTCUSD.csv, norm std of diffs: 0.0007422632985567171
# file: ETHUSD.csv, norm std of diffs: 0.00737314864892973
# file: SOLUSD.csv, norm std of diffs: 0.010285652817791284

# %%
class price_vs_random_walk_dataset(Dataset):
    def __init__(self, price_array, random_walk_array):
        self.data = np.concatenate([price_array, random_walk_array], axis=0)
        self.labels = np.concatenate([np.ones(price_array.shape[0]), np.zeros(random_walk_array.shape[0])])

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        # if self.data[idx][0] == 0:
        #     x = torch.tensor(self.data[idx])
        # else:
        #     x = torch.tensor(self.data[idx]) / torch.tensor(self.data[idx][0])
        x = torch.tensor(self.data[idx])
        y = torch.tensor(self.labels[idx])
        # if y == 1:
            # y = torch.tensor([0, 1])
            # x += .002
        # else:
            # y = torch.tensor([1, 0])
        return torch.unsqueeze(x, 0).to(torch.float), torch.unsqueeze(torch.unsqueeze(y, 0), 0).to(torch.float)
    
train_test_split = .8
train_size = int(train_test_split * len(prices))

train_dl = DataLoader(price_vs_random_walk_dataset(prices[:train_size], random_walks[:train_size]), batch_size=128, shuffle=True)
test_dl = DataLoader(price_vs_random_walk_dataset(prices[train_size:], random_walks[train_size:]), batch_size=128, shuffle=True)

# %%
itrtr = iter(train_dl)
x, y, = next(itrtr)
x.shape, y.shape
# Out:
# (torch.Size([128, 1, 784]), torch.Size([128, 1, 1]))

# %%
#plot all samples
for i in range(len(x)):
    if y[i] == 1:
        plt.plot(x[i,0,:].numpy(), c='b')
    else:
        plt.plot(x[i,0,:].numpy(), c='r')

# %%
#plot single sample
rand_idxs = np.random.randint(0, len(x), 100)
for i in rand_idxs:
    if y[i] == 1:
        plt.plot(x[i,0,:], c='b', alpha=.5)
        break
    
for i in rand_idxs:
    if y[i] == 0:
        plt.plot(x[i,0,:], c='r', alpha=.5)
        break

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(1, 64, 3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5) 
        self.fc1 = nn.LazyLinear(128)
        self.fc2 = nn.LazyLinear(1)
        self.loss_fn = nn.BCEWithLogitsLoss()
        
        
    def forward(self, x):
        x = x.reshape(-1, 1, 28, 28)
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        return x
    
print(Model()(x).shape)
# Out:
# torch.Size([128, 1])

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = Model()
model = model.to(device) # GPU
train_losses = []
test_losses = []

def train_loop(model, data, lr=.001):
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    _losses = []
    for i, (x, y) in enumerate(data):
        if torch.isinf(x).any():
            print('x has nans')
        x = x.to(device) # GPU
        y = y.to(device)
        opt.zero_grad()
        x_hat = model(x)
        if torch.isnan(x_hat).any() or torch.isinf(x_hat).any():
            print('x_hat has nans')
        loss = model.loss_fn(x_hat.squeeze(), y.squeeze())
        loss.backward()
        opt.step()
        _losses.append(loss.detach().cpu().numpy())
        print(f'epoch: {epoch}, batch: {i}, loss: {loss}', end='\r')
    train_losses.append(np.mean(_losses))
    return model


def test_loop(model, data):
    model.eval()
    with torch.no_grad():
        _losses = []
        for i, (x, y) in enumerate(data):
            x = x.to(device) # GPU
            y = y.to(device)
            x_hat = model(x)
            loss = model.loss_fn(x_hat.squeeze(), y.squeeze())
            print(f'epoch: {epoch}, batch: {i}, loss: {loss}', end='\r')
            _losses.append(loss.detach().cpu().numpy())
        test_losses.append(np.mean(_losses))

# %%
num_epochs = 1000
for epoch in range(num_epochs):
    model = train_loop(model, train_dl, lr=0.0005)
    test_loop(model, test_dl)
# Out:
# epoch: 44, batch: 296, loss: 0.038246195763349535
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 3
#       1 num_epochs = 1000
#       2 for epoch in range(num_epochs):
# ----> 3     model = train_loop(model, train_dl, lr=0.0005)
#       4     test_loop(model, test_dl)
#
# Cell In[19], line 20, in train_loop(model, data, lr)
#      18     print('x_hat has nans')
#      19 loss = model.loss_fn(x_hat.squeeze(), y.squeeze())
# ---> 20 loss.backward()
#      21 opt.step()
#      22 _losses.append(loss.detach().cpu().numpy())
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
plt.plot([loss for loss in train_losses])
plt.plot([loss for loss in test_losses])

# %%
#test on test set
model.eval()
losses = []
with torch.no_grad():
    for i, (x, y) in enumerate(test_dl):
        x = x.to(device) # GPU
        y = y.to(device)
        x_hat = model(x)
        loss = model.loss_fn(x_hat, y)
        print(f'batch: {i}, loss: {loss}', end='\r')
        losses.append(loss.detach().cpu().numpy())
print(f'test loss: {np.mean(losses)}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 9
#       7 y = y.to(device)
#       8 x_hat = model(x)
# ----> 9 loss = model.loss_fn(x_hat, y)
#      10 print(f'batch: {i}, loss: {loss}', end='\r')
#      11 losses.append(loss.detach().cpu().numpy())
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\torch\nn\modules\loss.py:725, in BCEWithLogitsLoss.forward(self, input, target)
#     724 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 725     return F.binary_cross_entropy_with_logits(input, target,
#     726                                               self.weight,
#     727                                               pos_weight=self.pos_weight,
#     728                                               reduction=self.reduction)
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\torch\nn\functional.py:3193, in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    3190     reduction_enum = _Reduction.get_enum(reduction)
#    3192 if not (target.size() == input.size()):
# -> 3193     raise ValueError(f"Target size ({target.size()}) must be the same as input size ({input.size()})")
#    3195 return torch.binary_cross_entropy_with_logits(input, target, weight, pos_weight, reduction_enum)
#
# ValueError: Target size (torch.Size([128, 1, 1])) must be the same as input size (torch.Size([128, 1]))

# %%
#save model
savepath = os.path.join('model_checkpoints', 'random_walk_classification-detrend-2d.pt')
torch.save(model.state_dict(), savepath)
