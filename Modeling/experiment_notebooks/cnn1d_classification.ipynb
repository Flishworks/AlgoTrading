# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

sys.path.append(r'C:\Users\avido\Documents\other code\AlgoTrading')
import utils

# %%
#open and combine all data
base_key = 'BTCUSD'
other_keys =('ETHUSD', 'SOLUSD', 'DOTUSD', 'ADAUSD', 'ALGOUSD')
full_df = pd.read_csv(os.path.join('..', 'data', 'scraped_OHLC_7-13-2023', base_key+'.csv'))
full_df['dtime'] = pd.to_datetime(full_df['dtime'], format='%Y-%m-%d %H:%M:%S')
full_df.set_index('dtime', inplace = True)
full_df.drop(columns=['time'], inplace=True)
full_df = full_df.add_prefix(base_key+'_')

for key in other_keys:
    price_data = pd.read_csv(os.path.join('..', 'data', 'scraped_OHLC_7-13-2023', key+'.csv'))
    price_data['dtime'] = pd.to_datetime(price_data['dtime'], format='%Y-%m-%d %H:%M:%S')
    price_data.set_index('dtime', inplace = True)
    price_data.drop(columns=['time'], inplace=True)
    price_data = price_data.add_prefix(key+'_')
    full_df = pd.merge_asof(full_df, price_data, left_index=True, right_index=True, direction='nearest')

full_df.dropna(inplace=True, axis=0, how='all')

#normalize 'vwap', 'volume', 'count' data
norm_df = full_df.copy()
for key in full_df.keys():
    if key.endswith(('vwap', 'volume', 'count')):
        norm_df[key] = (full_df[key] - full_df[key].mean()) / full_df[key].std()

# %%
norm_df.values.shape
# Out:
# (630528, 42)

# %%
norm_df
# Out:
#                      BTCUSD_open  BTCUSD_high  BTCUSD_low  BTCUSD_close  \
# dtime
# 2022-04-13 17:33:00      41054.5      41054.5     41054.5       41054.5
# 2022-04-13 17:34:00      41054.5      41054.5     41000.0       41000.0
# 2022-04-13 17:35:00      41000.0      41001.6     40991.8       41001.5
# 2022-04-13 17:36:00      41001.6      41001.6     40950.2       40950.2
# 2022-04-13 17:37:00      40950.1      40950.2     40933.2       40933.2
# ...                          ...          ...         ...           ...
# 2023-07-13 16:29:00      30924.5      30924.5     30900.0       30900.0
# 2023-07-13 16:30:00      30900.0      30914.9     30900.0       30914.6
# 2023-07-13 16:31:00      30914.6      30914.6     30890.5       30890.5
# 2023-07-13 16:32:00      30874.5      30874.5     30862.5       30867.3
# 2023-07-13 16:33:00      30863.4      30863.4     30863.4       30863.4
#
#                      BTCUSD_vwap  BTCUSD_volume  BTCUSD_count  ETHUSD_open  \
# dtime
# 2022-04-13 17:33:00     2.777088      -0.199009     -0.329345      3077.99
# 2022-04-13 17:34:00     2.773286      -0.182037      0.240725      3077.99
# 2022-04-13 17:35:00     2.767672      -0.190197     -0.129820      3075.37
# 2022-04-13 17:36:00     2.763706      -0.098493     -0.101317      3075.39
# 2022-04-13 17:37:00     2.757848      -0.256153     -0.329345      3070.95
# ...                          ...            ...           ...          ...
# 2023-07-13 16:29:00     1.121427       1.806502      1.893929      1959.43
# 2023-07-13 16:30:00     1.120464      -0.171135      0.155215      1957.60
# 2023-07-13 16:31:00     1.119240       0.035841      1.295355      1958.00
# 2023-07-13 16:32:00     1.115079       0.095359      0.867803      1955.54
# 2023-07-13 16:33:00     1.113986      -0.260515     -0.557373      1955.54
#
#                      ETHUSD_high  ETHUSD_low  ...  ADAUSD_vwap  ADAUSD_volume  \
# dtime                                         ...
# 2022-04-13 17:33:00      3077.99     3077.99  ...     3.003636       0.136680
# 2022-04-13 17:34:00      3078.00     3076.14  ...     3.002958      -0.143306
# 2022-04-13 17:35:00      3075.40     3075.37  ...    -1.000672      -0.143450
# 2022-04-13 17:36:00      3075.39     3073.39  ...     3.005654      -0.143347
# 2022-04-13 17:37:00      3070.95     3069.94  ...     3.000183      -0.018628
# ...                          ...         ...  ...          ...            ...
# 2023-07-13 16:29:00      1959.43     1955.26  ...     0.318652       1.212515
# 2023-07-13 16:30:00      1958.00     1957.14  ...     0.318980       0.212512
# 2023-07-13 16:31:00      1958.00     1955.86  ...     0.316934      -0.075247
# 2023-07-13 16:32:00      1955.54     1954.49  ...     0.311401       2.115505
# 2023-07-13 16:33:00      1955.54     1954.49  ...     0.306509       0.763800
#
#                      ADAUSD_count  ALGOUSD_open  ALGOUSD_high  ALGOUSD_low  \
# dtime
# 2022-04-13 17:33:00      0.043855       0.74163       0.74163      0.74163
# 2022-04-13 17:34:00     -0.226992       0.73939       0.73939      0.73939
# 2022-04-13 17:35:00     -0.317274       0.73939       0.73939      0.73939
# 2022-04-13 17:36:00     -0.226992       0.73939       0.73939      0.73939
# 2022-04-13 17:37:00      0.224419       0.73803       0.73803      0.73803
# ...                           ...           ...           ...          ...
# 2023-07-13 16:29:00      1.849497       0.11248       0.11258      0.11237
# 2023-07-13 16:30:00      0.946676       0.11234       0.11283      0.11218
# 2023-07-13 16:31:00      0.314701       0.11248       0.11268      0.11223
# 2023-07-13 16:32:00      3.294011       0.11218       0.11218      0.11161
# 2023-07-13 16:33:00      1.307804       0.11190       0.11190      0.11190
#
#                      ALGOUSD_close  ALGOUSD_vwap  ALGOUSD_volume  \
# dtime
# 2022-04-13 17:33:00        0.74163     -0.608540       -0.089799
# 2022-04-13 17:34:00        0.73939      3.950679       -0.089220
# 2022-04-13 17:35:00        0.73939     -0.608540       -0.089799
# 2022-04-13 17:36:00        0.73939     -0.608540       -0.089799
# 2022-04-13 17:37:00        0.73803      3.942293       -0.089219
# ...                            ...           ...             ...
# 2023-07-13 16:29:00        0.11237      0.084725       -0.012944
# 2023-07-13 16:30:00        0.11283      0.085465        5.402125
# 2023-07-13 16:31:00        0.11223      0.085773        2.481050
# 2023-07-13 16:32:00        0.11190      0.081149        0.997524
# 2023-07-13 16:33:00        0.11190     -0.608540       -0.089799
#
#                      ALGOUSD_count
# dtime
# 2022-04-13 17:33:00      -0.290110
# 2022-04-13 17:34:00      -0.052402
# 2022-04-13 17:35:00      -0.290110
# 2022-04-13 17:36:00      -0.290110
# 2022-04-13 17:37:00      -0.052402
# ...                            ...
# 2023-07-13 16:29:00       0.660723
# 2023-07-13 16:30:00       5.890303
# 2023-07-13 16:31:00       2.800096
# 2023-07-13 16:32:00       5.177178
# 2023-07-13 16:33:00      -0.290110
#
# [630528 rows x 42 columns]

# %%
class price_dataset(Dataset):
    def __init__(self, df, window_size, target_key, target_window):
        self.df = df
        self.window_size = window_size
        self.target_key = target_key
        self.target_window = target_window

    def __len__(self):
        return len(self.df) - self.window_size - self.target_window

    def __getitem__(self, idx):
        chunk = self.df.iloc[idx:idx+self.window_size+self.target_window]
        
        y_chunk = chunk[self.target_key].iloc[self.window_size:self.window_size+self.target_window]
        x_chunk = chunk.iloc[0:self.window_size]
        
        #determine y value before as either buy, sell, hold
        if x_chunk[self.target_key].iloc[-10:-1].mean() * 1.01 < y_chunk.iloc[-10:-1].mean(): #if price is up 1% at the end of the time window
            y = torch.tensor([1, 0, 0]).type(torch.float32)
        elif x_chunk[self.target_key].iloc[-10:-1].mean() * 0.99 > y_chunk.iloc[-10:-1].mean(): #if price is down 1% at the end of the time window
            y = torch.tensor([0, 1, 0]).type(torch.float32)
        else:
            y = torch.tensor([0, 0, 1]).type(torch.float32)
        
        #divide by first value to normalize, but only the price columns (not vwap, volume or count)
        for key in self.df.columns:
            if not key.endswith(('vwap', 'volume', 'count')):
                if chunk[key].iloc[0] != 0:
                    chunk[key] = chunk[key] / chunk[key].iloc[0] - 1
                elif chunk[key].max() != 0:
                    chunk[key] = chunk[key] / chunk[key].max() - 1
                else:
                    chunk[key] = 0
        
        #re-slice chunks now that it has been normalized
        y_chunk = chunk[self.target_key].iloc[self.window_size:self.window_size+self.target_window]
        x_chunk = chunk.iloc[0:self.window_size]
        x = torch.tensor(x_chunk.values).type(torch.float32)
        x = x.swapaxes(0,1)
        y_chunk = torch.tensor(y_chunk.values).type(torch.float32)

        return x, y, y_chunk
    

train_window_size = 60 * 8
target_window_size = 120 
batch_size = 512
train_test_split = 0.8
num_input_chans = len(norm_df.keys())
train_dl = DataLoader(price_dataset(norm_df[0:int(.8*len(norm_df))], train_window_size, 'BTCUSD_close', target_window_size), batch_size=batch_size, shuffle=True)
test_dl = DataLoader(price_dataset(norm_df[int(.8*len(norm_df)):], train_window_size, 'BTCUSD_close', target_window_size), batch_size=batch_size, shuffle=True)

# %%
itrtr = iter(train_dl)
x, y, y_chunk = next(itrtr)
x.shape, y.shape, y_chunk.shape
# Out:
# C:\Users\avido\AppData\Local\Temp\ipykernel_29336\4216523635.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk[key] = chunk[key] / chunk[key].iloc[0] - 1
# C:\Users\avido\AppData\Local\Temp\ipykernel_29336\4216523635.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk[key] = chunk[key] / chunk[key].max() - 1
# (torch.Size([512, 42, 480]), torch.Size([512, 3]), torch.Size([512, 120]))

# %%
#plot random sample
rand_idx = np.random.randint(0, len(x))
plt.plot(np.arange(train_window_size), x[rand_idx,0,:].numpy())
plt.plot(np.arange(train_window_size, train_window_size+target_window_size), y_chunk[rand_idx,:].numpy())
print(y[rand_idx])
# Out:
# tensor([0., 0., 1.])

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv1d(num_input_chans, 32, 3, padding=1)
        self.conv2 = nn.Conv1d(32, 32, 3, padding=1)
        self.conv3 = nn.Conv1d(32, 32, 3, padding=1)
        self.conv4 = nn.Conv1d(32, 32, 3, padding=1)
        self.fc1 = nn.LazyLinear(128)
        self.fc2 = nn.LazyLinear(64)
        self.fc3 = nn.LazyLinear(3)
        self.loss_fn = nn.BCELoss()
        
        
        
    def forward(self, x):
        x = self.conv1(x)
        x = F.leaky_relu(F.max_pool1d(x, 2))
        x = self.conv2(x)
        x = F.leaky_relu(F.max_pool1d(x, 2))
        x = self.conv3(x)
        x = F.leaky_relu(F.max_pool1d(x, 2))
        x = self.conv4(x)
        x = F.leaky_relu(F.max_pool1d(x, 2))
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.leaky_relu(x)
        x = self.fc2(x)
        x = F.leaky_relu(x)
        x = self.fc3(x)
        x = F.sigmoid(x)
        return x
    
model = Model()
print(model(x).shape)
# Out:
# torch.Size([512, 3])

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

losses = []
def train(model, data, lr=.0001, epochs=10):
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    for epoch in range(epochs):
        for x, y, _ in data:
            x = x.to(device) # GPU
            y = y.to(device)
            opt.zero_grad()
            x_hat = model(x)
            loss = model.loss_fn(x_hat, y)
            loss.backward()
            opt.step()
            losses.append(loss)
            print(f'epoch: {epoch}, loss: {loss}', end='\r')
    return model

model = model.to(device) # GPU
train(model, train_dl, lr=0.001, epochs=100)
# Out:
# C:\Users\avido\AppData\Local\Temp\ipykernel_29336\4216523635.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk[key] = chunk[key] / chunk[key].iloc[0] - 1
# epoch: 0, loss: 0.6604381799697876
# C:\Users\avido\AppData\Local\Temp\ipykernel_29336\4216523635.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk[key] = chunk[key] / chunk[key].max() - 1
# epoch: 0, loss: 0.26204243302345276
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[178], line 20
#      17     return model
#      19 model = model.to(device) # GPU
# ---> 20 train(model, train_dl, lr=0.001, epochs=100)
#
# Cell In[178], line 7, in train(model, data, lr, epochs)
#       5 opt = torch.optim.Adam(model.parameters(), lr=lr)
#       6 for epoch in range(epochs):
# ----> 7     for x, y, _ in data:
#       8         x = x.to(device) # GPU
#       9         y = y.to(device)
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\torch\utils\data\dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[173], line 38, in price_dataset.__getitem__(self, idx)
#      36 y_chunk = chunk[self.target_key].iloc[self.window_size:self.window_size+self.target_window]
#      37 x_chunk = chunk.iloc[0:self.window_size]
# ---> 38 x = torch.tensor(x_chunk.values).type(torch.float32)
#      39 x = x.swapaxes(0,1)
#      40 y_chunk = torch.tensor(y_chunk.values).type(torch.float32)
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\pandas\core\frame.py:11735, in DataFrame.values(self)
#   11661 @property
#   11662 def values(self) -> np.ndarray:
#   11663     """
#   11664     Return a Numpy representation of the DataFrame.
#   11665
#    (...)
#   11733            ['monkey', nan, None]], dtype=object)
#   11734     """
# > 11735     self._consolidate_inplace()
#   11736     return self._mgr.as_array()
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\pandas\core\generic.py:5980, in NDFrame._consolidate_inplace(self)
#    5977 def f():
#    5978     self._mgr = self._mgr.consolidate()
# -> 5980 self._protect_consolidate(f)
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\pandas\core\generic.py:5968, in NDFrame._protect_consolidate(self, f)
#    5966     return f()
#    5967 blocks_before = len(self._mgr.blocks)
# -> 5968 result = f()
#    5969 if len(self._mgr.blocks) != blocks_before:
#    5970     self._clear_item_cache()
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\pandas\core\generic.py:5978, in NDFrame._consolidate_inplace.<locals>.f()
#    5977 def f():
# -> 5978     self._mgr = self._mgr.consolidate()
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\pandas\core\internals\managers.py:688, in BaseBlockManager.consolidate(self)
#     686 bm = type(self)(self.blocks, self.axes, self.refs, verify_integrity=False)
#     687 bm._is_consolidated = False
# --> 688 bm._consolidate_inplace()
#     689 return bm
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\pandas\core\internals\managers.py:1870, in BlockManager._consolidate_inplace(self)
#    1868     self.blocks = _consolidate(self.blocks)
#    1869 else:
# -> 1870     self.blocks, self.refs = _consolidate_with_refs(self.blocks, self.refs)
#    1871 self._is_consolidated = True
#    1872 self._known_consolidated = True
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\pandas\core\internals\managers.py:2347, in _consolidate_with_refs(blocks, refs)
#    2345 for (_can_consolidate, dtype), group_blocks_refs in grouper:
#    2346     group_blocks, group_refs = list(zip(*list(group_blocks_refs)))
# -> 2347     merged_blocks, consolidated = _merge_blocks(
#    2348         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2349     )
#    2350     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2351     if consolidated:
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\pandas\core\internals\managers.py:2378, in _merge_blocks(blocks, dtype, can_consolidate)
#    2371 new_values: ArrayLike
#    2373 if isinstance(blocks[0].dtype, np.dtype):
#    2374     # error: List comprehension has incompatible type List[Union[ndarray,
#    2375     # ExtensionArray]]; expected List[Union[complex, generic,
#    2376     # Sequence[Union[int, float, complex, str, bytes, generic]],
#    2377     # Sequence[Sequence[Any]], SupportsArray]]
# -> 2378     new_values = np.vstack([b.values for b in blocks])  # type: ignore[misc]
#    2379 else:
#    2380     bvals = [blk.values for blk in blocks]
#
# File <__array_function__ internals>:200, in vstack(*args, **kwargs)
#
# File c:\Users\avido\Documents\other code\AlgoTrading\.venv\lib\site-packages\numpy\core\shape_base.py:296, in vstack(tup, dtype, casting)
#     294 if not isinstance(arrs, list):
#     295     arrs = [arrs]
# --> 296 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
plt.plot([np.log(loss.cpu().detach().numpy()) for loss in losses])

# %%
#plot an example from test set
x, y, y_chunk = next(iter(test_dl))
rand_idx = np.random.randint(0, len(x))
print(y[rand_idx])
print(model(x[rand_idx,:,:].unsqueeze(0).to(device)))
plt.plot(np.arange(train_window_size), x[rand_idx,0,:].numpy())
plt.plot(np.arange(train_window_size, train_window_size+target_window_size), y_chunk[rand_idx,:].numpy())
# Out:
# C:\Users\avido\AppData\Local\Temp\ipykernel_29336\4216523635.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk[key] = chunk[key] / chunk[key].iloc[0] - 1
# tensor([0., 0., 1.])
# tensor([[0.0305, 0.0198, 0.9542]], device='cuda:0', grad_fn=<SigmoidBackward0>)
